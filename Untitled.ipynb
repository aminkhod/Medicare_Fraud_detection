# %%
from neo4j import GraphDatabase

class HelloWorldExample:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def print_greeting(self, message):
        with self.driver.session() as session:
            greeting = session.write_transaction(self._create_and_return_greeting, message)
            print(greeting)

    @staticmethod
    def _create_and_return_greeting(tx, message):
        result = tx.run("CREATE (a:Greeting) "
                        "SET a.message = $message "
                        "RETURN a.message + ', from node ' + id(a)", message=message)
        return result.single()[0]


if __name__ == "__main__":
    greeter = HelloWorldExample("bolt://localhost:7687", "neo4j", "password")
    greeter.print_greeting("hello, world")
    greeter.close()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/neo4j/io/__init__.py in _connect(resolved_address, timeout, keep_alive)
#     928         log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 929         s.connect(resolved_address)
#     930         s.settimeout(t)
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ServiceUnavailable                        Traceback (most recent call last)
# <ipython-input-3-f4dd80fa1cd2> in <module>
#      23
#      24 if __name__ == "__main__":
# ---> 25     greeter = HelloWorldExample("bolt://localhost:7687", "neo4j", "password")
#      26     greeter.print_greeting("hello, world")
#      27     greeter.close()
#
# <ipython-input-3-f4dd80fa1cd2> in __init__(self, uri, user, password)
#       4
#       5     def __init__(self, uri, user, password):
# ----> 6         self.driver = GraphDatabase.driver(uri, auth=(user, password))
#       7
#       8     def close(self):
#
# ~/.local/lib/python3.6/site-packages/neo4j/__init__.py in driver(cls, uri, auth, **config)
#     181     def closed(self):
#     182         """ Return :const:`True` if closed, :const:`False` otherwise.
# --> 183         """
#     184         return self._closed
#     185
#
# ~/.local/lib/python3.6/site-packages/neo4j/__init__.py in bolt_driver(cls, target, auth, **config)
#     194     """
#     195
# --> 196     uri_scheme = "bolt"
#     197
#     198     def __new__(cls, uri, **config):
#
# ~/.local/lib/python3.6/site-packages/neo4j/__init__.py in open(cls, target, auth, **config)
#     357         return self
#     358
# --> 359     def __exit__(self, exc_type, exc_value, traceback):
#     360         self.close()
#     361
#
# ~/.local/lib/python3.6/site-packages/neo4j/io/__init__.py in open(cls, address, auth, pool_config, workspace_config, routing_context)
#     529
#     530         pool = cls(opener, pool_config, workspace_config, routing_context, address)
# --> 531         seeds = [pool.acquire() for _ in range(pool_config.init_size)]
#     532         pool.release(*seeds)
#     533         return pool
#
# ~/.local/lib/python3.6/site-packages/neo4j/io/__init__.py in <listcomp>(.0)
#     529
#     530         pool = cls(opener, pool_config, workspace_config, routing_context, address)
# --> 531         seeds = [pool.acquire() for _ in range(pool_config.init_size)]
#     532         pool.release(*seeds)
#     533         return pool
#
# ~/.local/lib/python3.6/site-packages/neo4j/io/__init__.py in acquire(self, access_mode, timeout, database)
#     543     def acquire(self, access_mode=None, timeout=None, database=None):
#     544         # The access_mode and database is not needed for a direct connection, its just there for consistency.
# --> 545         return self._acquire(self.address, timeout)
#     546
#     547
#
# ~/.local/lib/python3.6/site-packages/neo4j/io/__init__.py in _acquire(self, address, timeout)
#     407                     timeout = min(self.pool_config.connection_timeout, time_remaining())
#     408                     try:
# --> 409                         connection = self.opener(address, timeout)
#     410                     except ServiceUnavailable:
#     411                         self.remove(address)
#
# ~/.local/lib/python3.6/site-packages/neo4j/io/__init__.py in opener(addr, timeout)
#     526
#     527         def opener(addr, timeout):
# --> 528             return Bolt.open(addr, auth=auth, timeout=timeout, routing_context=routing_context, **pool_config)
#     529
#     530         pool = cls(opener, pool_config, workspace_config, routing_context, address)
#
# ~/.local/lib/python3.6/site-packages/neo4j/io/__init__.py in open(cls, address, auth, timeout, routing_context, **pool_config)
#     196             custom_resolver=pool_config.resolver,
#     197             ssl_context=pool_config.get_ssl_context(),
# --> 198             keep_alive=pool_config.keep_alive,
#     199         )
#     200
#
# ~/.local/lib/python3.6/site-packages/neo4j/io/__init__.py in connect(address, timeout, custom_resolver, ssl_context, keep_alive)
#    1047         raise ServiceUnavailable("Failed to resolve addresses for %s" % address)
#    1048     else:
# -> 1049         raise last_error
#
# ~/.local/lib/python3.6/site-packages/neo4j/io/__init__.py in connect(address, timeout, custom_resolver, ssl_context, keep_alive)
#    1037         try:
#    1038             host = address[0]
# -> 1039             s = _connect(resolved_address, timeout, keep_alive)
#    1040             s = _secure(s, host, ssl_context)
#    1041             return _handshake(s, address)
#
# ~/.local/lib/python3.6/site-packages/neo4j/io/__init__.py in _connect(resolved_address, timeout, keep_alive)
#     941         log.debug("[#0000]  C: <CLOSE> %s", resolved_address)
#     942         s.close()
# --> 943         raise ServiceUnavailable("Failed to establish connection to {!r} (reason {})".format(resolved_address, error))
#     944     else:
#     945         return s
#
# ServiceUnavailable: Failed to establish connection to IPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused)

# %%
from py2neo import Graph
graph = Graph()

tx = graph.begin()
for name in ["Alice", "Bob", "Carol"]:
    tx.append("CREATE (person:Person {name:{name}}) RETURN person", name=name)
alice, bob, carol = [result.one for result in tx.commit()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/py2neo/database/__init__.py in __new__(cls, profile, **settings)
#     189         try:
# --> 190             inst = cls._instances[profile]
#     191         except KeyError:
#
# KeyError: ConnectionProfile('bolt://neo4j@localhost:7687')
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in acquire(self, graph_name, readonly, timeout, force_reset)
#     516                 # Plan A: select a free connection from the pool
# --> 517                 cx = self._free_list.popleft()
#     518             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-7-5ada7f349d25> in <module>
#       1 from py2neo import Graph
# ----> 2 graph = Graph()
#       3
#       4 tx = graph.begin()
#       5 for name in ["Alice", "Bob", "Carol"]:
#
# ~/.local/lib/python3.6/site-packages/py2neo/database/__init__.py in __new__(cls, profile, name, **settings)
#     375
#     376     def __new__(cls, profile=None, name=None, **settings):
# --> 377         gs = GraphService(profile, **settings)
#     378         return gs[name]
#     379
#
# ~/.local/lib/python3.6/site-packages/py2neo/database/__init__.py in __new__(cls, profile, **settings)
#     197                 "max_age": settings.get("max_age"),
#     198             }
# --> 199             inst._connector = Connector.open(profile, **connector_settings)
#     200             inst._graphs = {}
#     201             cls._instances[profile] = inst
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in open(cls, profile, user_agent, init_size, max_size, max_age)
#     800             connector
#     801         """
# --> 802         return cls(profile, user_agent, init_size, max_size, max_age)
#     803
#     804     def __init__(self, profile, user_agent, init_size, max_size, max_age):
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in __init__(self, profile, user_agent, init_size, max_size, max_age)
#     806             profile, user_agent, init_size, max_size, max_age,
#     807             on_bind=self._bind_connection,
# --> 808             on_unbind=self._unbind_connection)
#     809         self._transactions = {}
#     810
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in open(cls, profile, user_agent, init_size, max_size, max_age, on_bind, on_unbind)
#     366         """
#     367         pool = cls(profile, user_agent, max_size, max_age, on_bind, on_unbind)
# --> 368         seeds = [pool.acquire() for _ in range(init_size or cls.default_init_size)]
#     369         for seed in seeds:
#     370             seed.release()
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in <listcomp>(.0)
#     366         """
#     367         pool = cls(profile, user_agent, max_size, max_age, on_bind, on_unbind)
# --> 368         seeds = [pool.acquire() for _ in range(init_size or cls.default_init_size)]
#     369         for seed in seeds:
#     370             seed.release()
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in acquire(self, graph_name, readonly, timeout, force_reset)
#     522                     cx = Connection.open(self.profile, user_agent=self.user_agent,
#     523                                          on_bind=self._on_bind, on_unbind=self._on_unbind,
# --> 524                                          on_release=lambda c: self.release(c))
#     525                     if cx.supports_multi():
#     526                         self._supports_multi = True
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in open(cls, profile, user_agent, on_bind, on_unbind, on_release)
#      97             from py2neo.client.bolt import Bolt
#      98             return Bolt.open(profile, user_agent=user_agent,
# ---> 99                              on_bind=on_bind, on_unbind=on_unbind, on_release=on_release)
#     100         elif profile.protocol == "http":
#     101             from py2neo.client.http import HTTP
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/bolt.py in open(cls, profile, user_agent, on_bind, on_unbind, on_release)
#     109         :param on_release:
#     110         """
# --> 111         wire = cls._connect(profile)
#     112         protocol_version = cls._handshake(wire)
#     113         subclass = cls._get_subclass(protocol_version)
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/bolt.py in _connect(cls, profile)
#     123     def _connect(cls, profile):
#     124         log.debug("[#%04X] C: (Dialing <%s>)", 0, profile.address)
# --> 125         wire = Wire.open(profile.address, keep_alive=True)
#     126         local_port = wire.local_address.port_number
#     127         log.debug("[#%04X] S: (Accepted)", local_port)
#
# ~/.local/lib/python3.6/site-packages/py2neo/wiring.py in open(cls, address, timeout, keep_alive)
#     151             s.setsockopt(SOL_SOCKET, SO_KEEPALIVE, 1)
#     152         s.settimeout(timeout)
# --> 153         s.connect(address)
#     154         return cls(s)
#     155
#
# ConnectionRefusedError: [Errno 111] Connection refused

# %%
from neomodel import StructuredNode, StringProperty, RelationshipTo, RelationshipFrom, config

config.DATABASE_URL = 'bolt://neo4j:test@localhost:7687'

class Book(StructuredNode):
    title = StringProperty(unique_index=True)
    author = RelationshipTo('Author', 'AUTHOR')

class Author(StructuredNode):
    name = StringProperty(unique_index=True)
    books = RelationshipFrom('Book', 'AUTHOR')

harry_potter = Book(title='Harry potter and the..').save()
rowling =  Author(name='J. K. Rowling').save()
harry_potter.author.connect(rowling)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-1525914e3180> in <module>
# ----> 1 from neomodel import StructuredNode, StringProperty, RelationshipTo, RelationshipFrom, config
#       2
#       3 config.DATABASE_URL = 'bolt://neo4j:test@localhost:7687'
#       4
#       5 class Book(StructuredNode):
#
# ~/.local/lib/python3.6/site-packages/neomodel/__init__.py in <module>
#       1 # pep8: noqa
#       2 import pkg_resources
# ----> 3 from .core import *
#       4 from neomodel.exceptions import *
#       5 from .util import clear_neo4j_database, change_neo4j_password
#
# ~/.local/lib/python3.6/site-packages/neomodel/core.py in <module>
#       7 from neomodel.hooks import hooks
#       8 from neomodel.properties import Property, PropertyManager
# ----> 9 from neomodel.util import Database, classproperty, _UnsavedNode, _get_node_properties
#      10
#      11 db = Database()
#
# ~/.local/lib/python3.6/site-packages/neomodel/util.py in <module>
#       6 from threading import local
#       7
# ----> 8 from neo4j.v1 import GraphDatabase, basic_auth, CypherError, SessionError
#       9 from neo4j.types.graph import Node
#      10
#
# ImportError: cannot import name 'CypherError'
