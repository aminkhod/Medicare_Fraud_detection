# %%
from neo4j import GraphDatabase

class HelloWorldExample:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def print_greeting(self, message):
        with self.driver.session() as session:
            greeting = session.write_transaction(self._create_and_return_greeting, message)
            print(greeting)

    @staticmethod
    def _create_and_return_greeting(tx, message):
        result = tx.run("CREATE (a:Greeting) "
                        "SET a.message = $message "
                        "RETURN a.message + ', from node ' + id(a)", message=message)
        return result.single()[0]


if __name__ == "__main__":
    greeter = HelloWorldExample("bolt://localhost:7474", "neo4j", "neo4j")
    greeter.print_greeting("hello, world")
    greeter.close()
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/neobolt/direct.py in _secure(s, host, ssl_context, **config)
#     853         try:
# --> 854             s = ssl_context.wrap_socket(s, server_hostname=host if HAS_SNI and host else None)
#     855         except SSLError as cause:
#
# /usr/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#
# /usr/lib/python3.6/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     816                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 817                     self.do_handshake()
#     818
#
# /usr/lib/python3.6/ssl.py in do_handshake(self, block)
#    1076                 self.settimeout(None)
# -> 1077             self._sslobj.do_handshake()
#    1078         finally:
#
# /usr/lib/python3.6/ssl.py in do_handshake(self)
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#
# SSLError: [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:852)
#
# The above exception was the direct cause of the following exception:
#
# SecurityError                             Traceback (most recent call last)
# <ipython-input-2-d42f057aec99> in <module>
#      23
#      24 if __name__ == "__main__":
# ---> 25     greeter = HelloWorldExample("bolt://localhost:7474", "neo4j", "password")
#      26     greeter.print_greeting("hello, world")
#      27     greeter.close()
#
# <ipython-input-2-d42f057aec99> in __init__(self, uri, user, password)
#       4
#       5     def __init__(self, uri, user, password):
# ----> 6         self.driver = GraphDatabase.driver(uri, auth=(user, password))
#       7
#       8     def close(self):
#
# ~/.local/lib/python3.6/site-packages/neo4j/__init__.py in driver(cls, uri, **config)
#     106         :class:`.Driver` subclass instance directly.
#     107         """
# --> 108         return Driver(uri, **config)
#     109
#     110
#
# ~/.local/lib/python3.6/site-packages/neo4j/__init__.py in __new__(cls, uri, **config)
#     145         for subclass in Driver.__subclasses__():
#     146             if parsed.scheme == subclass.uri_scheme:
# --> 147                 return subclass(uri, **config)
#     148         raise ValueError("URI scheme %r not supported" % parsed.scheme)
#     149
#
# ~/.local/lib/python3.6/site-packages/neo4j/__init__.py in __new__(cls, uri, **config)
#     219
#     220         pool = ConnectionPool(connector, instance.address, **config)
# --> 221         pool.release(pool.acquire())
#     222         instance._pool = pool
#     223         instance._max_retry_time = config.get("max_retry_time", default_config["max_retry_time"])
#
# ~/.local/lib/python3.6/site-packages/neobolt/direct.py in acquire(self, access_mode)
#     713
#     714     def acquire(self, access_mode=None):
# --> 715         return self.acquire_direct(self.address)
#     716
#     717
#
# ~/.local/lib/python3.6/site-packages/neobolt/direct.py in acquire_direct(self, address)
#     606                 if can_create_new_connection:
#     607                     try:
# --> 608                         connection = self.connector(address, error_handler=self.connection_error_handler)
#     609                     except ServiceUnavailable:
#     610                         self.remove(address)
#
# ~/.local/lib/python3.6/site-packages/neo4j/__init__.py in connector(address, **kwargs)
#     216
#     217         def connector(address, **kwargs):
# --> 218             return connect(address, **dict(config, **kwargs))
#     219
#     220         pool = ConnectionPool(connector, instance.address, **config)
#
# ~/.local/lib/python3.6/site-packages/neobolt/direct.py in connect(address, **config)
#     970         raise ServiceUnavailable("Failed to resolve addresses for %s" % address)
#     971     else:
# --> 972         raise last_error
#
# ~/.local/lib/python3.6/site-packages/neobolt/direct.py in connect(address, **config)
#     961             host = address[0]
#     962             s = _connect(resolved_address, **config)
# --> 963             s, der_encoded_server_certificate = _secure(s, host, security_plan.ssl_context, **config)
#     964             connection = _handshake(s, address, der_encoded_server_certificate, **config)
#     965         except Exception as error:
#
# ~/.local/lib/python3.6/site-packages/neobolt/direct.py in _secure(s, host, ssl_context, **config)
#     857             error = SecurityError("Failed to establish secure connection to {!r}".format(cause.args[1]))
#     858             error.__cause__ = cause
# --> 859             raise error
#     860         else:
#     861             # Check that the server provides a certificate
#
# SecurityError: Failed to establish secure connection to '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:852)'

# %%
from py2neo import Graph
graph = Graph()

tx = graph.begin()
for name in ["Alice", "Bob", "Carol"]:
    tx.append("CREATE (person:Person {name:{name}}) RETURN person", name=name)
alice, bob, carol = [result.one for result in tx.commit()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/py2neo/database/__init__.py in __new__(cls, profile, **settings)
#     189         try:
# --> 190             inst = cls._instances[profile]
#     191         except KeyError:
#
# KeyError: ConnectionProfile('bolt://neo4j@localhost:7687')
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in acquire(self, graph_name, readonly, timeout, force_reset)
#     516                 # Plan A: select a free connection from the pool
# --> 517                 cx = self._free_list.popleft()
#     518             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# ClientError                               Traceback (most recent call last)
# <ipython-input-6-5ada7f349d25> in <module>
#       1 from py2neo import Graph
# ----> 2 graph = Graph()
#       3
#       4 tx = graph.begin()
#       5 for name in ["Alice", "Bob", "Carol"]:
#
# ~/.local/lib/python3.6/site-packages/py2neo/database/__init__.py in __new__(cls, profile, name, **settings)
#     375
#     376     def __new__(cls, profile=None, name=None, **settings):
# --> 377         gs = GraphService(profile, **settings)
#     378         return gs[name]
#     379
#
# ~/.local/lib/python3.6/site-packages/py2neo/database/__init__.py in __new__(cls, profile, **settings)
#     197                 "max_age": settings.get("max_age"),
#     198             }
# --> 199             inst._connector = Connector.open(profile, **connector_settings)
#     200             inst._graphs = {}
#     201             cls._instances[profile] = inst
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in open(cls, profile, user_agent, init_size, max_size, max_age)
#     800             connector
#     801         """
# --> 802         return cls(profile, user_agent, init_size, max_size, max_age)
#     803
#     804     def __init__(self, profile, user_agent, init_size, max_size, max_age):
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in __init__(self, profile, user_agent, init_size, max_size, max_age)
#     806             profile, user_agent, init_size, max_size, max_age,
#     807             on_bind=self._bind_connection,
# --> 808             on_unbind=self._unbind_connection)
#     809         self._transactions = {}
#     810
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in open(cls, profile, user_agent, init_size, max_size, max_age, on_bind, on_unbind)
#     366         """
#     367         pool = cls(profile, user_agent, max_size, max_age, on_bind, on_unbind)
# --> 368         seeds = [pool.acquire() for _ in range(init_size or cls.default_init_size)]
#     369         for seed in seeds:
#     370             seed.release()
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in <listcomp>(.0)
#     366         """
#     367         pool = cls(profile, user_agent, max_size, max_age, on_bind, on_unbind)
# --> 368         seeds = [pool.acquire() for _ in range(init_size or cls.default_init_size)]
#     369         for seed in seeds:
#     370             seed.release()
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in acquire(self, graph_name, readonly, timeout, force_reset)
#     522                     cx = Connection.open(self.profile, user_agent=self.user_agent,
#     523                                          on_bind=self._on_bind, on_unbind=self._on_unbind,
# --> 524                                          on_release=lambda c: self.release(c))
#     525                     if cx.supports_multi():
#     526                         self._supports_multi = True
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/__init__.py in open(cls, profile, user_agent, on_bind, on_unbind, on_release)
#      97             from py2neo.client.bolt import Bolt
#      98             return Bolt.open(profile, user_agent=user_agent,
# ---> 99                              on_bind=on_bind, on_unbind=on_unbind, on_release=on_release)
#     100         elif profile.protocol == "http":
#     101             from py2neo.client.http import HTTP
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/bolt.py in open(cls, profile, user_agent, on_bind, on_unbind, on_release)
#     117                         on_bind=on_bind, on_unbind=on_unbind, on_release=on_release)
#     118         bolt.__local_port = wire.local_address.port_number
# --> 119         bolt._hello()
#     120         return bolt
#     121
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/bolt.py in _hello(self)
#     211         self._send()
#     212         self._fetch()
# --> 213         self._audit(response)
#     214         self.connection_id = response.metadata.get("connection_id")
#     215         self.server_agent = response.metadata.get("server")
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/bolt.py in _audit(self, task)
#     418         """
#     419         try:
# --> 420             task.audit()
#     421         except Failure:
#     422             self.reset(force=True)
#
# ~/.local/lib/python3.6/site-packages/py2neo/client/bolt.py in audit(self)
#     779         if self._failure:
#     780             self.set_ignored()
# --> 781             raise self._failure
#     782
#     783     @property
#
# ClientError: [Security.Unauthorized] The client is unauthorized due to authentication failure.

# %%
from neomodel import StructuredNode, StringProperty, RelationshipTo, RelationshipFrom, config

config.DATABASE_URL = 'http://localhost:7474/'

class Book(StructuredNode):
    title = StringProperty(unique_index=True)
    author = RelationshipTo('Author', 'AUTHOR')

class Author(StructuredNode):
    name = StringProperty(unique_index=True)
    books = RelationshipFrom('Book', 'AUTHOR')

harry_potter = Book(title='Harry potter and the..').save()
rowling =  Author(name='J. K. Rowling').save()
harry_potter.author.connect(rowling)
# Out:
# ---------------------------------------------------------------------------
# ClassAlreadyDefined                       Traceback (most recent call last)
# <ipython-input-5-c775f2e62180> in <module>
#       3 config.DATABASE_URL = 'http://localhost:7474/'
#       4
# ----> 5 class Book(StructuredNode):
#       6     title = StringProperty(unique_index=True)
#       7     author = RelationshipTo('Author', 'AUTHOR')
#
# ~/.local/lib/python3.6/site-packages/neomodel/core.py in __new__(mcs, name, bases, namespace)
#     177                 db._NODE_CLASS_REGISTRY[label_set] = cls
#     178             else:
# --> 179                 raise ClassAlreadyDefined(cls, db._NODE_CLASS_REGISTRY)
#     180
#     181         return cls
#
# ClassAlreadyDefined: Class __main__.Book with labels Book already defined:
# {frozenset({'Book'}): <class '__main__.Book'>, frozenset({'Author'}): <class '__main__.Author'>}
